# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns 
import numpy as np
from scipy.stats import norm 
from sklearn.preprocessing import StandardScaler 
from scipy import stats
import warnings

# %matplotlib inline

# %% [markdown]
# # Exploracion de datos

# %%
df_train = pd.read_csv("train.csv")

# %%
df_train.head(5)
# Out:
#    Id  MSSubClass MSZoning  LotFrontage  LotArea Street Alley LotShape  \
# 0   1          60       RL         65.0     8450   Pave   NaN      Reg
# 1   2          20       RL         80.0     9600   Pave   NaN      Reg
# 2   3          60       RL         68.0    11250   Pave   NaN      IR1
# 3   4          70       RL         60.0     9550   Pave   NaN      IR1
# 4   5          60       RL         84.0    14260   Pave   NaN      IR1
#
#   LandContour Utilities  ... PoolArea PoolQC Fence MiscFeature MiscVal MoSold  \
# 0         Lvl    AllPub  ...        0    NaN   NaN         NaN       0      2
# 1         Lvl    AllPub  ...        0    NaN   NaN         NaN       0      5
# 2         Lvl    AllPub  ...        0    NaN   NaN         NaN       0      9
# 3         Lvl    AllPub  ...        0    NaN   NaN         NaN       0      2
# 4         Lvl    AllPub  ...        0    NaN   NaN         NaN       0     12
#
#   YrSold  SaleType  SaleCondition  SalePrice
# ...

# %%
df_train.shape
# Out:
# (1460, 81)

# %%
df_train.columns
# Out:
# Index(['Id', 'MSSubClass', 'MSZoning', 'LotFrontage', 'LotArea', 'Street',
#        'Alley', 'LotShape', 'LandContour', 'Utilities', 'LotConfig',
#        'LandSlope', 'Neighborhood', 'Condition1', 'Condition2', 'BldgType',
#        'HouseStyle', 'OverallQual', 'OverallCond', 'YearBuilt', 'YearRemodAdd',
#        'RoofStyle', 'RoofMatl', 'Exterior1st', 'Exterior2nd', 'MasVnrType',
#        'MasVnrArea', 'ExterQual', 'ExterCond', 'Foundation', 'BsmtQual',
#        'BsmtCond', 'BsmtExposure', 'BsmtFinType1', 'BsmtFinSF1',
#        'BsmtFinType2', 'BsmtFinSF2', 'BsmtUnfSF', 'TotalBsmtSF', 'Heating',
#        'HeatingQC', 'CentralAir', 'Electrical', '1stFlrSF', '2ndFlrSF',
#        'LowQualFinSF', 'GrLivArea', 'BsmtFullBath', 'BsmtHalfBath', 'FullBath',
#        'HalfBath', 'BedroomAbvGr', 'KitchenAbvGr', 'KitchenQual',
#        'TotRmsAbvGrd', 'Functional', 'Fireplaces', 'FireplaceQu', 'GarageType',
#        'GarageYrBlt', 'GarageFinish', 'GarageCars', 'GarageArea', 'GarageQual',
# ...

# %%
df_train.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1460 entries, 0 to 1459
# Data columns (total 81 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   Id             1460 non-null   int64
#  1   MSSubClass     1460 non-null   int64
#  2   MSZoning       1460 non-null   object
#  3   LotFrontage    1201 non-null   float64
#  4   LotArea        1460 non-null   int64
#  5   Street         1460 non-null   object
#  6   Alley          91 non-null     object
#  7   LotShape       1460 non-null   object
#  8   LandContour    1460 non-null   object
#  9   Utilities      1460 non-null   object
#  10  LotConfig      1460 non-null   object
#  11  LandSlope      1460 non-null   object
#  12  Neighborhood   1460 non-null   object
#  13  Condition1     1460 non-null   object
#  14  Condition2     1460 non-null   object
#  15  BldgType       1460 non-null   object
#  16  HouseStyle     1460 non-null   object
# ...

# %%
poi = df_train.describe()
df_train.describe()
# Out:
#                 Id   MSSubClass  LotFrontage        LotArea  OverallQual  \
# count  1460.000000  1460.000000  1201.000000    1460.000000  1460.000000
# mean    730.500000    56.897260    70.049958   10516.828082     6.099315
# std     421.610009    42.300571    24.284752    9981.264932     1.382997
# min       1.000000    20.000000    21.000000    1300.000000     1.000000
# 25%     365.750000    20.000000    59.000000    7553.500000     5.000000
# 50%     730.500000    50.000000    69.000000    9478.500000     6.000000
# 75%    1095.250000    70.000000    80.000000   11601.500000     7.000000
# max    1460.000000   190.000000   313.000000  215245.000000    10.000000
#
#        OverallCond    YearBuilt  YearRemodAdd   MasVnrArea   BsmtFinSF1  ...  \
# count  1460.000000  1460.000000   1460.000000  1452.000000  1460.000000  ...
# mean      5.575342  1971.267808   1984.865753   103.685262   443.639726  ...
# std       1.112799    30.202904     20.645407   181.066207   456.098091  ...
# ...

# %%
poi.columns
# Out:
# Index(['Id', 'MSSubClass', 'LotFrontage', 'LotArea', 'OverallQual',
#        'OverallCond', 'YearBuilt', 'YearRemodAdd', 'MasVnrArea', 'BsmtFinSF1',
#        'BsmtFinSF2', 'BsmtUnfSF', 'TotalBsmtSF', '1stFlrSF', '2ndFlrSF',
#        'LowQualFinSF', 'GrLivArea', 'BsmtFullBath', 'BsmtHalfBath', 'FullBath',
#        'HalfBath', 'BedroomAbvGr', 'KitchenAbvGr', 'TotRmsAbvGrd',
#        'Fireplaces', 'GarageYrBlt', 'GarageCars', 'GarageArea', 'WoodDeckSF',
#        'OpenPorchSF', 'EnclosedPorch', '3SsnPorch', 'ScreenPorch', 'PoolArea',
#        'MiscVal', 'MoSold', 'YrSold', 'SalePrice'],
#       dtype='object')

# %%
poi.shape
# Out:
# (8, 38)

# %%
#variables categoricas

# %%
df_train.describe(include=["O"])
# Out:
#        MSZoning Street Alley LotShape LandContour Utilities LotConfig  \
# count      1460   1460    91     1460        1460      1460      1460
# unique        5      2     2        4           4         2         5
# top          RL   Pave  Grvl      Reg         Lvl    AllPub    Inside
# freq       1151   1454    50      925        1311      1459      1052
#
#        LandSlope Neighborhood Condition1  ... GarageType GarageFinish  \
# count       1460         1460       1460  ...       1379         1379
# unique         3           25          9  ...          6            3
# top          Gtl        NAmes       Norm  ...     Attchd          Unf
# freq        1382          225       1260  ...        870          605
#
#        GarageQual GarageCond PavedDrive PoolQC  Fence MiscFeature SaleType  \
# count        1379       1379       1460      7    281          54     1460
# unique          5          5          3      3      4           4        9
# ...

# %%
df_train.describe(include=["O"]).columns
# Out:
# Index(['MSZoning', 'Street', 'Alley', 'LotShape', 'LandContour', 'Utilities',
#        'LotConfig', 'LandSlope', 'Neighborhood', 'Condition1', 'Condition2',
#        'BldgType', 'HouseStyle', 'RoofStyle', 'RoofMatl', 'Exterior1st',
#        'Exterior2nd', 'MasVnrType', 'ExterQual', 'ExterCond', 'Foundation',
#        'BsmtQual', 'BsmtCond', 'BsmtExposure', 'BsmtFinType1', 'BsmtFinType2',
#        'Heating', 'HeatingQC', 'CentralAir', 'Electrical', 'KitchenQual',
#        'Functional', 'FireplaceQu', 'GarageType', 'GarageFinish', 'GarageQual',
#        'GarageCond', 'PavedDrive', 'PoolQC', 'Fence', 'MiscFeature',
#        'SaleType', 'SaleCondition'],
#       dtype='object')

# %% [markdown]
# # Estudio de variable Target

# %%
#la variable que vamos a estudiar es SalePrice

# %%
df_train["SalePrice"].describe()
# Out:
# count      1460.000000
# mean     180921.195890
# std       79442.502883
# min       34900.000000
# 25%      129975.000000
# 50%      163000.000000
# 75%      214000.000000
# max      755000.000000
# Name: SalePrice, dtype: float64

# %%
df_train["SalePrice"].median()
# Out:
# 163000.0

# %%
df_train["SalePrice"].info()
# Out:
# <class 'pandas.core.series.Series'>
# RangeIndex: 1460 entries, 0 to 1459
# Series name: SalePrice
# Non-Null Count  Dtype
# --------------  -----
# 1460 non-null   int64
# dtypes: int64(1)
# memory usage: 11.5 KB

# %%
tiope=sns.displot(df_train["SalePrice"])
plt.xticks(rotation=30)
plt.axis(xmin=0, xmax=800000)
# Out:
# (0.0, 800000.0, 0.0, 185.85)

# %%
sns.displot(df_train["SalePrice"],kind="kde")

# %% [markdown]
# Se puede evidenciar que las distribucion de los precios no es normal, existe un agrupamiento de los datos que tienden a la izquierda

# %%
skw=df_train["SalePrice"].skew()
skw1=df_train["SalePrice"].kurt()

# %%
print ("The Skewnnes:", skw)
print ("The Kurtusis:", skw1)
# Out:
# The Skewnnes: 1.8828757597682129
# The Kurtusis: 6.536281860064529

# %% [markdown]
# Mediante el coeficiente de asimetria (Skewnnes) podemos ver que los datos tienden a reunirse bajo los valores
# de la mediana la mayor frecuencia de los datos tienden hacia la izquierda (Curva de asimetria positiva).
# En nuestros analasis esto quiere decir que aunque hay casa muy costosas la mayor cantidad
# se vendieron por un precio inferir a 160.000 US

# %% [markdown]
# # Vamos a ver las variables relevantes

# %%
#tomamos 5  variables 

#Variables Cuantitativas
#TotalBsmtSF.
#GrLivArea.


#Variables categoricas
#OverallQual 
#YearBuilt
#Street


#Estas variables se tomaron como hipotesis.

# %%
var = "TotalBsmtSF"
tboq=pd.concat([df_train["SalePrice"],df_train[var]],axis=1)
tboq.plot.scatter(x=var, y="SalePrice", ylim=(0, 800000))
# Out:
# <AxesSubplot:xlabel='TotalBsmtSF', ylabel='SalePrice'>

# %% [markdown]
# Se ve un correlacion donde crece el precio al crecer sotano, donde podemos decir que es una variable que influye en "SalePrice"

# %%
var="GrLivArea"
tbga= pd.concat([df_train["SalePrice"],df_train[var]], axis=1)
tbga.plot.scatter(y="SalePrice", x=var, ylim=(0, 800000))
# Out:
# <AxesSubplot:xlabel='GrLivArea', ylabel='SalePrice'>

# %% [markdown]
# Igual con la variable anterior esta tambien tiene correlacion vemos que
# cuando crece el area tambien el precio.

# %%
# Vamos con las variables categoricas

# %%
var="Street"
tbov=pd.concat([df_train["SalePrice"],df_train[var]],axis=1)
tbov.head(5)
# Out:
#    SalePrice Street
# 0     208500   Pave
# 1     181500   Pave
# 2     223500   Pave
# 3     140000   Pave
# 4     250000   Pave

# %%
rup=df_train.groupby(["Street"]).mean()["SalePrice"]
print(rup)
rup.plot.bar()
plt.show()
# Out:
# Street
# Grvl    130190.500000
# Pave    181130.538514
# Name: SalePrice, dtype: float64

# %%
df_train.groupby(["Street"]).describe()["SalePrice"]
# Out:
#          count           mean           std      min       25%       50%  \
# Street
# Grvl       6.0  130190.500000  65446.253991  55993.0   88250.0  114250.0
# Pave    1454.0  181130.538514  79446.597317  34900.0  130000.0  163000.0
#
#              75%       max
# Street
# Grvl    169650.0  228950.0
# Pave    214000.0  755000.0

# %% [markdown]
# Por las medias anteriores podemos ver que aunque una de las calles tiene un promedio
# mas alto referente al precio esto puede estar sesgados, por la cantidad de casas que
# fueron evaludas por la calle.
#
# ***Nota: POR TAL MOTIVO VAMOS A QUITAR ESTA VARIABLE DEL ANALISIS.***

# %%
#vamos por al caliadd de la casa

# %%
var=("OverallQual")
tbOvsale=pd.concat([df_train["SalePrice"], df_train[var]],axis=1)

# %%
fa, ax =plt.subplots(figsize=(8,6))
fig=sns.boxplot(x=var, y="SalePrice", data=tbOvsale)
fig.axis(ymin=0, ymax=800000)
# Out:
# (-0.5, 9.5, 0.0, 800000.0)

# %% [markdown]
# Esta  bastante clara la correlacion entre la calidad de la casa,
# al parecer es bastante
# importante a la hora de la compra

# %%
#vamos por el año de construccion de la casa

# %%
var="YearBuilt"
tbYB=pd.concat([df_train["SalePrice"], df_train[var]], axis=1)

# %%
fa, ax=plt.subplots(figsize=(20,8))
tkj=sns.boxplot(x=var, y="SalePrice", data=tbYB)
tkj.axis(ymin=0, ymax=800000)
plt.xticks(rotation=60)
plt.show
# Out:
# <function matplotlib.pyplot.show(close=None, block=None)>

# %% [markdown]
# Anque se ve una leve correlacion no es muy claro
# ya que hay casas viejas que se vendieron muy bien.

# %% [markdown]
# # Matriz de correlacion

# %%
#vamos a ver si tal vez existe alguna otra variable que sea 
#relevante ademas de ello vamos a ver que tan relevantes son las variables que ya analizamos

# %%
#funcion:
corrmat=df_train.corr()

# %%
f, ax=plt.subplots(figsize=(12,8))
sns.heatmap(corrmat, vmax=.8, square=True)
# Out:
# <AxesSubplot:>

# %% [markdown]
# Las varables que son mas claras son las que tiene mas correlacion
# pero veamoslo mas claro y con detalle

# %%
k=10
colsre= corrmat.nlargest(k, "SalePrice").index

# %%
#las variable mas relacionadas son 
colsre
# Out:
# Index(['SalePrice', 'OverallQual', 'GrLivArea', 'GarageCars', 'GarageArea',
#        'TotalBsmtSF', '1stFlrSF', 'FullBath', 'TotRmsAbvGrd', 'YearBuilt'],
#       dtype='object')

# %%
cm=np.corrcoef(df_train[colsre].values.T)

# %%
sns.set(font_scale=1.25)
hm=sns.heatmap(cm, cbar=True, annot=True, square=True, fmt=".2f", linewidths=.5, annot_kws={"size":10,}, 
               yticklabels=colsre.values, xticklabels=colsre.values)

# %% [markdown]
# Aca podemos evaludar varios puntos:
# 1.Hay dos variables "GarageArea" y "GarageCars" las cuales tiene un relacion
# directamente proporcional pues cuano crece una a la misma vez la otra. Asi que solo vamos a tomar una de las dos.
# 2.Otra variable que vamos a descartar es "1stflrSF", pues esta tiene una relacion directa con la variable "TotalBsmt SF" la cual ya evaluamos. Esta relacion se debe a que el piso uno siempre esta constrido sobre el sotano por lo cual tiene un area similar.
# 3.Tenemos una variable que no habiamos contemplado que es "FullBath.

# %%
#bien entonces las variables que vamos a evaluar van a ser: 
cols =['SalePrice', 'OverallQual', 'GrLivArea', 'GarageCars',
       'TotalBsmtSF', 'FullBath',  'YearBuilt']

# %%
sns.pairplot(df_train[cols], height=2.5)
plt.show
# Out:
# <function matplotlib.pyplot.show(close=None, block=None)>

# %% [markdown]
# # Modelo de predicion

# %% [markdown]
#
#    # Regresion simple

# %%
w=125
b=0

# %%
var="GrLivArea"

x=np.linspace(0,df_train[var].max(),100)
y=w*x+b

df_train.plot.scatter(x=var,y="SalePrice",ylim=(0,df_train["SalePrice"].max()*1.1))
plt.plot(x,y,"-r")
plt.show
# Out:
# *c* argument looks like a single numeric RGB or RGBA sequence, which should be avoided as value-mapping will have precedence in case its length matches with *x* & *y*.  Please use the *color* keyword-argument or provide a 2D array with a single row if you intend to specify the same RGB or RGBA value for all points.
# <function matplotlib.pyplot.show(close=None, block=None)>

# %%
from sklearn.linear_model import LinearRegression

#importar input y output
X_train=np.array(df_train["GrLivArea"]).reshape((-1,1))
Y_train=np.array(df_train["SalePrice"])
                 
# crear modelo

model=LinearRegression(fit_intercept=False)
model.fit(X_train, Y_train)

#imprimir parametros

print(f"intercepto (b):{model.intercept_}")
print(f"pendiente (w):{model.coef_}")
# Out:
# intercepto (b):0.0
# pendiente (w):[118.06909986]

# %%
w=118.069
b=0

# %%
#calculo de predicion
df_train["pred"]=df_train["GrLivArea"]*w+b

# %%
#calculo de la funcion de error
df_train["diff"]=df_train["pred"]-df_train["SalePrice"]
df_train["cuad"]=df_train["diff"]**2
df_train.head()
# Out:
#    Id  MSSubClass MSZoning  LotFrontage  LotArea Street Alley LotShape  \
# 0   1          60       RL         65.0     8450   Pave   NaN      Reg
# 1   2          20       RL         80.0     9600   Pave   NaN      Reg
# 2   3          60       RL         68.0    11250   Pave   NaN      IR1
# 3   4          70       RL         60.0     9550   Pave   NaN      IR1
# 4   5          60       RL         84.0    14260   Pave   NaN      IR1
#
#   LandContour Utilities  ... MiscFeature MiscVal MoSold YrSold SaleType  \
# 0         Lvl    AllPub  ...         NaN       0      2   2008       WD
# 1         Lvl    AllPub  ...         NaN       0      5   2007       WD
# 2         Lvl    AllPub  ...         NaN       0      9   2008       WD
# 3         Lvl    AllPub  ...         NaN       0      2   2006       WD
# 4         Lvl    AllPub  ...         NaN       0     12   2008       WD
#
#   SaleCondition SalePrice        pred       diff          cuad
# ...

# %%
df_train["cuad"].mean()
# Out:
# 3176828273.391324

# %%
from sklearn.metrics import r2_score

# %%
print("Efectividad: %2f" % (r2_score(df_train["SalePrice"],df_train["pred"])*100))
# Out:
# Efectividad: 49.628432

# %% [markdown]
# Con la regresion simple nos da una efectividad por debajo del 50%
# Tenemos que considerar que este modelo se construyo con una sola variable para aumentar el porcentaje haremos un modelo mas robusto con las demas variables de interes.
#
# De no funcionar aplicariamos otra tecnica para predecir la variable "SalePrice".

# %% [markdown]
# # Regresio lineal multiple
