# %%
#importar Librerias

# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import numpy as np
from scipy.stats import norm 
from sklearn.preprocessing import StandardScaler 
from scipy import stats
import warnings

# %matplotlib inline

# %% [markdown]
# # Exploracion de datos

# %%
#importar datos  
df_train = pd.read_csv("train.csv")

# %%
#este no muetra un pequeña parte del dataframe
df_train.head(5)
# Out:
#    Id  MSSubClass MSZoning  LotFrontage  LotArea Street Alley LotShape  \
# 0   1          60       RL         65.0     8450   Pave   NaN      Reg
# 1   2          20       RL         80.0     9600   Pave   NaN      Reg
# 2   3          60       RL         68.0    11250   Pave   NaN      IR1
# 3   4          70       RL         60.0     9550   Pave   NaN      IR1
# 4   5          60       RL         84.0    14260   Pave   NaN      IR1
#
#   LandContour Utilities  ... PoolArea PoolQC Fence MiscFeature MiscVal MoSold  \
# 0         Lvl    AllPub  ...        0    NaN   NaN         NaN       0      2
# 1         Lvl    AllPub  ...        0    NaN   NaN         NaN       0      5
# 2         Lvl    AllPub  ...        0    NaN   NaN         NaN       0      9
# 3         Lvl    AllPub  ...        0    NaN   NaN         NaN       0      2
# 4         Lvl    AllPub  ...        0    NaN   NaN         NaN       0     12
#
#   YrSold  SaleType  SaleCondition  SalePrice
# ...

# %%
#mostar las dimenciones de la dataframe

df_train.shape
# Out:
# (1460, 81)

# %%
#mostrar todas las columnas 
df_train.columns
# Out:
# Index(['Id', 'MSSubClass', 'MSZoning', 'LotFrontage', 'LotArea', 'Street',
#        'Alley', 'LotShape', 'LandContour', 'Utilities', 'LotConfig',
#        'LandSlope', 'Neighborhood', 'Condition1', 'Condition2', 'BldgType',
#        'HouseStyle', 'OverallQual', 'OverallCond', 'YearBuilt', 'YearRemodAdd',
#        'RoofStyle', 'RoofMatl', 'Exterior1st', 'Exterior2nd', 'MasVnrType',
#        'MasVnrArea', 'ExterQual', 'ExterCond', 'Foundation', 'BsmtQual',
#        'BsmtCond', 'BsmtExposure', 'BsmtFinType1', 'BsmtFinSF1',
#        'BsmtFinType2', 'BsmtFinSF2', 'BsmtUnfSF', 'TotalBsmtSF', 'Heating',
#        'HeatingQC', 'CentralAir', 'Electrical', '1stFlrSF', '2ndFlrSF',
#        'LowQualFinSF', 'GrLivArea', 'BsmtFullBath', 'BsmtHalfBath', 'FullBath',
#        'HalfBath', 'BedroomAbvGr', 'KitchenAbvGr', 'KitchenQual',
#        'TotRmsAbvGrd', 'Functional', 'Fireplaces', 'FireplaceQu', 'GarageType',
#        'GarageYrBlt', 'GarageFinish', 'GarageCars', 'GarageArea', 'GarageQual',
# ...

# %%
#Mostrar columnas en especifico ojos con los corchete
df_train[["SalePrice", "Id", "LotArea"]]
# Out:
#       SalePrice    Id  LotArea
# 0        208500     1     8450
# 1        181500     2     9600
# 2        223500     3    11250
# 3        140000     4     9550
# 4        250000     5    14260
# ...         ...   ...      ...
# 1455     175000  1456     7917
# 1456     210000  1457    13175
# 1457     266500  1458     9042
# 1458     142125  1459     9717
# 1459     147500  1460     9937
#
# [1460 rows x 3 columns]

# %%
#mostar valores nulos y type de las columnas

df_train.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1460 entries, 0 to 1459
# Data columns (total 81 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   Id             1460 non-null   int64
#  1   MSSubClass     1460 non-null   int64
#  2   MSZoning       1460 non-null   object
#  3   LotFrontage    1201 non-null   float64
#  4   LotArea        1460 non-null   int64
#  5   Street         1460 non-null   object
#  6   Alley          91 non-null     object
#  7   LotShape       1460 non-null   object
#  8   LandContour    1460 non-null   object
#  9   Utilities      1460 non-null   object
#  10  LotConfig      1460 non-null   object
#  11  LandSlope      1460 non-null   object
#  12  Neighborhood   1460 non-null   object
#  13  Condition1     1460 non-null   object
#  14  Condition2     1460 non-null   object
#  15  BldgType       1460 non-null   object
#  16  HouseStyle     1460 non-null   object
# ...

# %%
#ver inf general de todas las variables numericas

df_train.describe()
# Out:
#                 Id   MSSubClass  LotFrontage        LotArea  OverallQual  \
# count  1460.000000  1460.000000  1201.000000    1460.000000  1460.000000
# mean    730.500000    56.897260    70.049958   10516.828082     6.099315
# std     421.610009    42.300571    24.284752    9981.264932     1.382997
# min       1.000000    20.000000    21.000000    1300.000000     1.000000
# 25%     365.750000    20.000000    59.000000    7553.500000     5.000000
# 50%     730.500000    50.000000    69.000000    9478.500000     6.000000
# 75%    1095.250000    70.000000    80.000000   11601.500000     7.000000
# max    1460.000000   190.000000   313.000000  215245.000000    10.000000
#
#        OverallCond    YearBuilt  YearRemodAdd   MasVnrArea   BsmtFinSF1  ...  \
# count  1460.000000  1460.000000   1460.000000  1452.000000  1460.000000  ...
# mean      5.575342  1971.267808   1984.865753   103.685262   443.639726  ...
# std       1.112799    30.202904     20.645407   181.066207   456.098091  ...
# ...

# %%
#usar funcines para columnas en especifico del dataframe 
df_train[["SalePrice", "PoolArea"]].max()
# Out:
# SalePrice    755000
# PoolArea        738
# dtype: int64

# %%
# variables categoricas 
df_train.describe(include=["O"])
# Out:
#        MSZoning Street Alley LotShape LandContour Utilities LotConfig  \
# count      1460   1460    91     1460        1460      1460      1460
# unique        5      2     2        4           4         2         5
# top          RL   Pave  Grvl      Reg         Lvl    AllPub    Inside
# freq       1151   1454    50      925        1311      1459      1052
#
#        LandSlope Neighborhood Condition1  ... GarageType GarageFinish  \
# count       1460         1460       1460  ...       1379         1379
# unique         3           25          9  ...          6            3
# top          Gtl        NAmes       Norm  ...     Attchd          Unf
# freq        1382          225       1260  ...        870          605
#
#        GarageQual GarageCond PavedDrive PoolQC  Fence MiscFeature SaleType  \
# count        1379       1379       1460      7    281          54     1460
# unique          5          5          3      3      4           4        9
# ...

# %%
df_train.describe(include=["O"]).columns
# Out:
# Index(['MSZoning', 'Street', 'Alley', 'LotShape', 'LandContour', 'Utilities',
#        'LotConfig', 'LandSlope', 'Neighborhood', 'Condition1', 'Condition2',
#        'BldgType', 'HouseStyle', 'RoofStyle', 'RoofMatl', 'Exterior1st',
#        'Exterior2nd', 'MasVnrType', 'ExterQual', 'ExterCond', 'Foundation',
#        'BsmtQual', 'BsmtCond', 'BsmtExposure', 'BsmtFinType1', 'BsmtFinType2',
#        'Heating', 'HeatingQC', 'CentralAir', 'Electrical', 'KitchenQual',
#        'Functional', 'FireplaceQu', 'GarageType', 'GarageFinish', 'GarageQual',
#        'GarageCond', 'PavedDrive', 'PoolQC', 'Fence', 'MiscFeature',
#        'SaleType', 'SaleCondition'],
#       dtype='object')

# %% [markdown]
# # Estudio de la variable target

# %%
#tomamos 5  variables 

#OverallQual 
#YearBuilt.
#TotalBsmtSF.
#GrLivArea.
#Street

# %%
df_train["SalePrice"].describe()
# Out:
# count      1460.000000
# mean     180921.195890
# std       79442.502883
# min       34900.000000
# 25%      129975.000000
# 50%      163000.000000
# 75%      214000.000000
# max      755000.000000
# Name: SalePrice, dtype: float64

# %%
df_train.groupby(["Street"]).describe()["SalePrice"]
# Out:
#          count           mean           std      min       25%       50%  \
# Street
# Grvl       6.0  130190.500000  65446.253991  55993.0   88250.0  114250.0
# Pave    1454.0  181130.538514  79446.597317  34900.0  130000.0  163000.0
#
#              75%       max
# Street
# Grvl    169650.0  228950.0
# Pave    214000.0  755000.0

# %%
grp_st=df_train.groupby(["Street"]).mean()["SalePrice"]
print(grp_st)
(grp_st.plot.bar())
plt.show()
# Out:
# Street
# Grvl    130190.500000
# Pave    181130.538514
# Name: SalePrice, dtype: float64

# %%
tiope=sns.displot(df_train["SalePrice"]);
plt.xticks(rotation=30)
plt.axis(xmin=0, xmax=900000)
# Out:
# (0.0, 900000.0, 0.0, 185.85)

# %%
sns.displot(df_train["SalePrice"],kind="kde")

# %%
df_train["SalePrice"].skew()
# Out:
# 1.8828757597682129

# %%
print("Skewnees: %f" % df_train["SalePrice"].skew())
# Out:
# Skewnees: 1.882876

# %%
#vamos a ver la distribucion de las 
#otras variables segun SalePrice

# %%
var = 'GrLivArea'

# %%
tbvarsl = pd.concat([df_train["SalePrice"],df_train[var]], axis=1)

# %%
tbvarsl.head(5)
# Out:
#    SalePrice  GrLivArea
# 0     208500       1710
# 1     181500       1262
# 2     223500       1786
# 3     140000       1717
# 4     250000       2198

# %%
tbvarsl.plot.scatter(x=var, y="SalePrice", ylim=(0,800000))
# Out:
# <AxesSubplot:xlabel='GrLivArea', ylabel='SalePrice'>

# %%
var = "TotalBsmtSF"

# %%
tbvartb = pd.concat([df_train["SalePrice"],df_train[var]],axis=1)
tbvartb.plot.scatter(x=var, y="SalePrice", ylim=(0,800000))
# Out:
# <AxesSubplot:xlabel='TotalBsmtSF', ylabel='SalePrice'>

# %%
var="OverallQual"
tbOvsale=pd.concat([df_train["SalePrice"],df_train[var]],axis=1)

# %%
fa, ax = plt.subplots(figsize=(8,6))
fig=sns.boxplot(x=var, y="SalePrice", data=tbOvsale)
fig.axis(ymin=0,ymax=800000)
# Out:
# (-0.5, 9.5, 0.0, 800000.0)

# %%
var="YearBuilt"
tbYbsl = pd.concat([df_train["SalePrice"],df_train[var]],axis=1)

# %% [raw]
# tbYbsl.head(5)

# %%
f, ax= plt.subplots(figsize=(20,8))
tkj=sns.boxplot(x=var, y="SalePrice",data=tbYbsl)
plt.xticks(rotation=60)
tkj.axis(ymin=0, ymax=800000)
# Out:
# (-0.5, 111.5, 0.0, 800000.0)

# %% [markdown]
# # Matriz de correlacion

# %%
#se declara la funcion y despues se grafica

# %%
#la funcion es esta  

corrmat= df_train.corr()

# %%
#luego se arma la grafica que es asi: 
f, ax= plt.subplots(figsize=(12,9))
sns.heatmap(corrmat, vmax=.8, square=True)
# Out:
# <AxesSubplot:>

# %% [markdown]
# # Matriz de correlacion con numero,ademas de funcion que me saca las columnas mas relacionadas

# %%
k=10

# %%
#Esta es la funcion para sacar a las columnas mas relacionadas
cols = corrmat.nlargest(k,"SalePrice")["SalePrice"].index

# %%
cols
# Out:
# Index(['SalePrice', 'OverallQual', 'GrLivArea', 'GarageCars', 'GarageArea',
#        'TotalBsmtSF', '1stFlrSF', 'FullBath', 'TotRmsAbvGrd', 'YearBuilt'],
#       dtype='object')

# %%
cm= np.corrcoef(df_train[cols].values.T)
cm
# Out:
# array([[1.        , 0.7909816 , 0.70862448, 0.6404092 , 0.62343144,
#         0.61358055, 0.60585218, 0.56066376, 0.53372316, 0.52289733],
#        [0.7909816 , 1.        , 0.59300743, 0.60067072, 0.56202176,
#         0.5378085 , 0.47622383, 0.55059971, 0.42745234, 0.57232277],
#        [0.70862448, 0.59300743, 1.        , 0.46724742, 0.46899748,
#         0.4548682 , 0.56602397, 0.63001165, 0.82548937, 0.19900971],
#        [0.6404092 , 0.60067072, 0.46724742, 1.        , 0.88247541,
#         0.43458483, 0.43931681, 0.46967204, 0.36228857, 0.53785009],
#        [0.62343144, 0.56202176, 0.46899748, 0.88247541, 1.        ,
#         0.48666546, 0.48978165, 0.40565621, 0.33782212, 0.47895382],
#        [0.61358055, 0.5378085 , 0.4548682 , 0.43458483, 0.48666546,
#         1.        , 0.81952998, 0.32372241, 0.28557256, 0.391452  ],
#        [0.60585218, 0.47622383, 0.56602397, 0.43931681, 0.48978165,
#         0.81952998, 1.        , 0.38063749, 0.40951598, 0.28198586],
# ...

# %%
sns.set(font_scale=1.25)
hm =sns.heatmap(cm, cbar=True, annot=True, square=True, fmt=".2f",linewidths=.5, annot_kws={"size":10,},  yticklabels=cols.values, xticklabels=cols.values)
#annot pone los numeros de cada cuadrante 
#annot_kws gradua lo grande de los numero s

# %%
sns.set()

# %%
cols =['SalePrice', 'OverallQual', 'GrLivArea', 'GarageCars',
       'TotalBsmtSF', 'FullBath',  'YearBuilt']

# %%
sns.pairplot(df_train[cols], height=2.5)
plt.show
# Out:
# <function matplotlib.pyplot.show(close=None, block=None)>
